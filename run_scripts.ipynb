# %%
import s3fs 
import xarray as xr
import boto3
import dask
import dask.array
fs_s3 = s3fs.S3FileSystem()
s3path = 's3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/thetao_Omon_GFDL-CM4_omip1_r1i1p1f1_gr_170801-172712.nc'
remote_file_obj = fs_s3.open(s3path, mode='rb')
s3path = 's3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/thetao_Omon_GFDL-CM4_omip1_r1i1p1f1_gr_172801-174712.nc'
remote_file_obj2 = fs_s3.open(s3path, mode='rb')
dataset = []
dataset.append(remote_file_obj)
dataset.append(remote_file_obj2)
dask = dask.array.from_array(dataset)
ds = xr.open_mfdataset(dask, chunks={'time': 1}, combine='by_coords')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/dask/array/__init__.py in <module>
#       5     from .blockwise import blockwise, atop
# ----> 6     from .core import (Array, block, concatenate, stack, from_array, store,
#       7                        map_blocks, to_hdf5, to_npy_stack, from_npy_stack,
#
# /opt/tljh/user/lib/python3.7/site-packages/dask/array/core.py in <module>
#      38                      parse_bytes, has_keyword, M, ndimlist)
# ---> 39 from ..compatibility import (unicode, zip_longest,
#      40                              Iterable, Iterator, Mapping)
#
# ImportError: cannot import name 'zip_longest' from 'dask.compatibility' (/opt/tljh/user/lib/python3.7/site-packages/dask/compatibility.py)
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
s3path = 's3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/thetao_Omon_GFDL-CM4_omip1_r1i1p1f1_gr_172801-174712.nc'
remote_file_obj = fs_s3.open(s3path, mode='rb')
ds2 = xr.open_dataset(remote_file_obj)
xr.Dataset.merge(ds, ds2)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-0461de589b65> in <module>
#       2 remote_file_obj = fs_s3.open(s3path, mode='rb')
#       3 ds2 = xr.open_dataset(remote_file_obj)
# ----> 4 xr.Dataset.merge(ds, ds2)
#
# /opt/tljh/user/lib/python3.7/site-packages/xarray/core/dataset.py in merge(self, other, inplace, overwrite_vars, compat, join, fill_value)
#    3680             compat=compat,
#    3681             join=join,
# -> 3682             fill_value=fill_value,
#    3683         )
#    3684         return self._replace(**merge_result._asdict())
#
# /opt/tljh/user/lib/python3.7/site-packages/xarray/core/merge.py in dataset_merge_method(dataset, other, overwrite_vars, compat, join, fill_value)
#     901
#     902     return merge_core(
# --> 903         objs, compat, join, priority_arg=priority_arg, fill_value=fill_value
#     904     )
#     905
#
# ...

# %%
remote_file_obj = fs_s3.open(s3path, mode='rb')
ds = xr.open_dataset(remote_file_obj)
dataset = ds
for file in 's3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/':
    remote_file_obj = fs_s3.open(file, mode='rb')
    ds = xr.open_dataset(remote_file_object)
    xr.Dataset.merge(dataset, ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e4e706146dc1> in <module>
#       3 dataset = ds
#       4 for file in 's3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/':
# ----> 5     remote_file_obj = fs_s3.open(file, mode='rb')
#       6     ds = xr.open_dataset(remote_file_object)
#       7     xr.Dataset.merge(dataset, ds)
#
# /opt/tljh/user/lib/python3.7/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     842                 autocommit=ac,
#     843                 cache_options=cache_options,
# --> 844                 **kwargs
#     845             )
#     846             if not ac:
#
# /opt/tljh/user/lib/python3.7/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
# ...

# %%
fs_s3.get('s3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/*.nc', .)
# Out:
#   File "<ipython-input-6-6ae2c320bb86>", line 1
#     fs_s3.get('s3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/*.nc', .)
#                                                                                                            ^
# SyntaxError: invalid syntax

# %%
import s3fs 
import xarray as xr
import boto3
fs_s3 = s3fs.S3FileSystem('s3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/')

# %%
fs_s3.open('s3://gfdl-esgf/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/thetao_Omon_GFDL-CM4_omip1_r1i1p1f1_gr_170801-172712.nc')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/s3fs/core.py in info(self, path, version_id, refresh)
#     529                 out = self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
# --> 530                                     Key=key, **version_id_kw(version_id), **self.req_kw)
#     531                 return {
#
# /opt/tljh/user/lib/python3.7/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     199                                                        **kwargs)
# --> 200         return method(**additional_kwargs)
#     201
#
# /opt/tljh/user/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#
# ...

# %%
import urllib
opener = urllib.URLopener()
myurl = "https://gfdl-esgf.s3-us-west-2.amazonaws.com/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/thetao_Omon_GFDL-CM4_omip1_r1i1p1f1_gr_170801-172712.nc"
myfile = opener.open(myurl)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a2069518a2a9> in <module>
#       1 import urllib
# ----> 2 opener = urllib.URLopener()
#       3 myurl = "https://gfdl-esgf.s3-us-west-2.amazonaws.com/CMIP6/OMIP/NOAA-GFDL/GFDL-CM4/omip1/r1i1p1f1/Omon/thetao/gr/v20180701/thetao_Omon_GFDL-CM4_omip1_r1i1p1f1_gr_170801-172712.nc"
#       4 myfile = opener.open(myurl)
#
# AttributeError: module 'urllib' has no attribute 'URLopener'

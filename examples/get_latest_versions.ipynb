# %%
import intake, intake_esm

# %% [markdown]
# ## Load the catalog

# %%
col_url = "https://cmip6-nc.s3.us-east-2.amazonaws.com/esgf-world.json"

# %%
from dask_gateway import Gateway
from dask.distributed import Client
def launchDask(options):
    #TODO try, except
    gateway = Gateway()
    clusters = gateway.list_clusters()
    clusters
    if len(clusters) >0:
        cluster = gateway.connect(clusters[0].name)
        print("lets close existing connection")#or shut down and start afresh cluster.shutdown(). otherwise I dunno how to apply custom options
        cluster.shutdown()
        
        cluster = gateway.new_cluster(options)
    else:
        cluster = gateway.new_cluster(options)
    return(cluster)

gateway = Gateway()
options = gateway.cluster_options()
options.worker_memory=8

cluster = launchDask(options)


from distributed import Client
client = Client(cluster)
client
cluster.adapt(minimum=0, maximum=30)
# Out:
# lets close existing connection

# %%
client
# Out:
# <Client: 'tls://192.168.56.33:8786' processes=0 threads=0, memory=0 B>

# %%
col = intake.open_esm_datastore(col_url)

# %%
esmcol_data = col.esmcol_data

# %%
cat_T = col.search(experiment_id=['historical'],
                 mip_table='Omon',
                 ensemble_member=["r1i1p1f1"],
                 model=['CESM2', 'CESM2-FV2', 'CESM2-WACCM-FV2','CIESM','IPSL-CM6A-LR','MPI-ESM1-2-HR','MPI-ESM1-2-LR','MIROC6','CanESM5',
                        'MPI-ESM-1-2-HAM','MRI-ESM2-0','SAM0-UNICON'],
                 #model=['GFDL-CM4','GFDL-ESM4'],
                 grid_label=['gn'],
                 variable=["thetao"])
               #  version=['v20190308', 'v20191120', 'v20200220','v20191108','v20190323','v20190731','v20190710','v20180803',
                #          'v20191007','v20190627','v20190311','v20190429','v20190627','v20191205','v20190914','v20190815','v20191108'])

# %%
cat_T #there are 11 distinct versions, 137 assets
# Out:
# <p><strong>gfdltest catalog with 12 dataset(s) from 137 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institute</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>model</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>modeling_realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>mip_table</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ensemble_member</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>temporal subset</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>137</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat_T.df.groupby(['model']).nunique()#CanESM5 has two versions
# Out:
#                  project  institute  experiment_id  frequency  modeling_realm  \
# model
# CESM2                  1          1              1          1               1
# CESM2-FV2              1          1              1          1               1
# CESM2-WACCM-FV2        1          1              1          1               1
# CIESM                  1          1              1          1               1
# CanESM5                1          1              1          1               1
# IPSL-CM6A-LR           1          1              1          1               1
# MIROC6                 1          1              1          1               1
# MPI-ESM-1-2-HAM        1          1              1          1               1
# MPI-ESM1-2-HR          1          1              1          1               1
# MPI-ESM1-2-LR          1          1              1          1               1
# MRI-ESM2-0             1          1              1          1               1
# SAM0-UNICON            1          1              1          1               1
#
#                  mip_table  ensemble_member  grid_label  variable  \
# model
# CESM2                    1                1           1         1
# CESM2-FV2                1                1           1         1
# CESM2-WACCM-FV2          1                1           1         1
# CIESM                    1                1           1         1
# CanESM5                  1                1           1         1
# IPSL-CM6A-LR             1                1           1         1
# MIROC6                   1                1           1         1
# MPI-ESM-1-2-HAM          1                1           1         1
# MPI-ESM1-2-HR            1                1           1         1
# MPI-ESM1-2-LR            1                1           1         1
# MRI-ESM2-0               1                1           1         1
# SAM0-UNICON              1                1           1         1
#
#                  temporal subset  version  path
# model
# CESM2                          1        1     1
# CESM2-FV2                      4        1     4
# CESM2-WACCM-FV2                4        1     4
# CIESM                          4        1     4
# CanESM5                       17        2    34
# IPSL-CM6A-LR                   2        1     2
# MIROC6                        17        1    17
# MPI-ESM-1-2-HAM                9        1     9
# MPI-ESM1-2-HR                 33        1    33
# MPI-ESM1-2-LR                  9        1     9
# MRI-ESM2-0                     3        1     3
# SAM0-UNICON                   17        1    17

# %%
cat_T.df[cat_T.df['model']=='CanESM5']  #there are 2 distinct versions
# Out:
#    project institute    model experiment_id frequency modeling_realm  \
# 0    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 1    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 2    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 3    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 4    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 5    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 6    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 7    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 8    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 9    CMIP6     CCCma  CanESM5    historical       mon          ocean
# 10   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 11   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 12   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 13   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 14   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 15   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 16   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 17   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 18   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 19   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 20   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 21   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 22   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 23   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 24   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 25   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 26   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 27   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 28   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 29   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 30   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 31   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 32   CMIP6     CCCma  CanESM5    historical       mon          ocean
# 33   CMIP6     CCCma  CanESM5    historical       mon          ocean
#
#    mip_table ensemble_member grid_label variable temporal subset    version  \
# 0       Omon        r1i1p1f1         gn   thetao   185001-186012  v20190306
# 1       Omon        r1i1p1f1         gn   thetao   186101-187012  v20190306
# 2       Omon        r1i1p1f1         gn   thetao   187101-188012  v20190306
# 3       Omon        r1i1p1f1         gn   thetao   188101-189012  v20190306
# 4       Omon        r1i1p1f1         gn   thetao   189101-190012  v20190306
# 5       Omon        r1i1p1f1         gn   thetao   190101-191012  v20190306
# 6       Omon        r1i1p1f1         gn   thetao   191101-192012  v20190306
# 7       Omon        r1i1p1f1         gn   thetao   192101-193012  v20190306
# 8       Omon        r1i1p1f1         gn   thetao   193101-194012  v20190306
# 9       Omon        r1i1p1f1         gn   thetao   194101-195012  v20190306
# 10      Omon        r1i1p1f1         gn   thetao   195101-196012  v20190306
# 11      Omon        r1i1p1f1         gn   thetao   196101-197012  v20190306
# 12      Omon        r1i1p1f1         gn   thetao   197101-198012  v20190306
# 13      Omon        r1i1p1f1         gn   thetao   198101-199012  v20190306
# 14      Omon        r1i1p1f1         gn   thetao   199101-200012  v20190306
# 15      Omon        r1i1p1f1         gn   thetao   200101-201012  v20190306
# 16      Omon        r1i1p1f1         gn   thetao   201101-201412  v20190306
# 17      Omon        r1i1p1f1         gn   thetao   185001-186012  v20190429
# 18      Omon        r1i1p1f1         gn   thetao   186101-187012  v20190429
# 19      Omon        r1i1p1f1         gn   thetao   187101-188012  v20190429
# 20      Omon        r1i1p1f1         gn   thetao   188101-189012  v20190429
# 21      Omon        r1i1p1f1         gn   thetao   189101-190012  v20190429
# 22      Omon        r1i1p1f1         gn   thetao   190101-191012  v20190429
# 23      Omon        r1i1p1f1         gn   thetao   191101-192012  v20190429
# 24      Omon        r1i1p1f1         gn   thetao   192101-193012  v20190429
# 25      Omon        r1i1p1f1         gn   thetao   193101-194012  v20190429
# 26      Omon        r1i1p1f1         gn   thetao   194101-195012  v20190429
# 27      Omon        r1i1p1f1         gn   thetao   195101-196012  v20190429
# 28      Omon        r1i1p1f1         gn   thetao   196101-197012  v20190429
# 29      Omon        r1i1p1f1         gn   thetao   197101-198012  v20190429
# 30      Omon        r1i1p1f1         gn   thetao   198101-199012  v20190429
# 31      Omon        r1i1p1f1         gn   thetao   199101-200012  v20190429
# 32      Omon        r1i1p1f1         gn   thetao   200101-201012  v20190429
# 33      Omon        r1i1p1f1         gn   thetao   201101-201412  v20190429
#
#                                                  path
# 0   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 1   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 2   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 3   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 4   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 5   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 6   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 7   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 8   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 9   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 10  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 11  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 12  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 13  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 14  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 15  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 16  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 17  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 18  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 19  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 20  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 21  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 22  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 23  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 24  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 25  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 26  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 27  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 28  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 29  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 30  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 31  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 32  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 33  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...

# %%
def latest_version(ds):
    """filters latest DRS versions of datasets only"""
    ds=ds.df.sort_values(['version']).groupby(['temporal subset','model','mip_table','institute','variable','ensemble_member','grid_label','experiment_id'],as_index=False).last()
    return ds

# %%
cat_T_new = latest_version(cat_T)

# %%
cat_T_new[cat_T_new['model']=='CanESM5'] #one distinct version only, latest one.
# Out:
#     temporal subset    model mip_table institute variable ensemble_member  \
# 3     185001-186012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 16    186101-187012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 23    187101-188012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 28    188101-189012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 35    189101-190012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 44    190101-191012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 51    191101-192012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 56    192101-193012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 63    193101-194012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 68    194101-195012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 80    195101-196012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 85    196101-197012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 92    197101-198012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 97    198101-199012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 104   199101-200012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 112   200101-201012  CanESM5      Omon     CCCma   thetao        r1i1p1f1
# 119   201101-201412  CanESM5      Omon     CCCma   thetao        r1i1p1f1
#
#     grid_label experiment_id project frequency modeling_realm    version  \
# 3           gn    historical   CMIP6       mon          ocean  v20190429
# 16          gn    historical   CMIP6       mon          ocean  v20190429
# 23          gn    historical   CMIP6       mon          ocean  v20190429
# 28          gn    historical   CMIP6       mon          ocean  v20190429
# 35          gn    historical   CMIP6       mon          ocean  v20190429
# 44          gn    historical   CMIP6       mon          ocean  v20190429
# 51          gn    historical   CMIP6       mon          ocean  v20190429
# 56          gn    historical   CMIP6       mon          ocean  v20190429
# 63          gn    historical   CMIP6       mon          ocean  v20190429
# 68          gn    historical   CMIP6       mon          ocean  v20190429
# 80          gn    historical   CMIP6       mon          ocean  v20190429
# 85          gn    historical   CMIP6       mon          ocean  v20190429
# 92          gn    historical   CMIP6       mon          ocean  v20190429
# 97          gn    historical   CMIP6       mon          ocean  v20190429
# 104         gn    historical   CMIP6       mon          ocean  v20190429
# 112         gn    historical   CMIP6       mon          ocean  v20190429
# 119         gn    historical   CMIP6       mon          ocean  v20190429
#
#                                                   path
# 3    s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 16   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 23   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 28   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 35   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 44   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 51   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 56   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 63   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 68   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 80   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 85   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 92   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 97   s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 104  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 112  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...
# 119  s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/histo...

# %%
cat_T = intake.open_esm_datastore(cat_T_new,esmcol_data=esmcol_data)

# %%
cat_T #newer esm data store with recent versions, 137 assets to 120 assets
# Out:
# <p><strong>gfdltest catalog with 12 dataset(s) from 120 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>temporal subset</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>model</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>mip_table</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institute</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>ensemble_member</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>project</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>modeling_realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>120</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat_T['CMIP6.CCCma.CanESM5.historical.Omon']
# Out:
#         <p>
#             <ul>
#                 <li><strong>Name</strong>                 : CMIP6.CCCma.CanESM5.historical.Omon</li>
#                 <li><strong>Num of xarray.Dataset</strong>: 1</li>
#                 <li><strong>Num of assets</strong>        : 17</li>
#                 <li><strong>Aggregation columns</strong>  : ['variable', 'ensemble_member', 'temporal subset']</li>
#             </ul>
#         </p>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ensemble_member</th>
#       <th>temporal subset</th>
#       <th>path</th>
#       <th>variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>r1i1p1f1</td>
#       <td>185001-186012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_185001-186012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>r1i1p1f1</td>
#       <td>186101-187012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_186101-187012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>r1i1p1f1</td>
#       <td>187101-188012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_187101-188012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>r1i1p1f1</td>
#       <td>188101-189012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_188101-189012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>r1i1p1f1</td>
#       <td>189101-190012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_189101-190012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>r1i1p1f1</td>
#       <td>190101-191012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_190101-191012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>r1i1p1f1</td>
#       <td>191101-192012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_191101-192012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>r1i1p1f1</td>
#       <td>192101-193012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_192101-193012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>r1i1p1f1</td>
#       <td>193101-194012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_193101-194012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>r1i1p1f1</td>
#       <td>194101-195012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_194101-195012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>r1i1p1f1</td>
#       <td>195101-196012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_195101-196012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>r1i1p1f1</td>
#       <td>196101-197012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_196101-197012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>r1i1p1f1</td>
#       <td>197101-198012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_197101-198012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>r1i1p1f1</td>
#       <td>198101-199012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_198101-199012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>r1i1p1f1</td>
#       <td>199101-200012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_199101-200012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>r1i1p1f1</td>
#       <td>200101-201012</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_200101-201012.nc</td>
#       <td>thetao</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>r1i1p1f1</td>
#       <td>201101-201412</td>
#       <td>s3://esgf-world/CMIP6/CMIP/CCCma/CanESM5/historical/r1i1p1f1/Omon/thetao/gn/v20190429/thetao_Omon_CanESM5_historical_r1i1p1f1_gn_201101-201412.nc</td>
#       <td>thetao</td>
#     </tr>
#   </tbody>
# </table>
